# %% [markdown]
# # CPI Inflation
#
# Plot CPI Inflation using World Bank data.

# %%
library(DBI)
library(plutoDbR)
library(plutoR)
library(tidyverse)
options("scipen"=999)
options(stringsAsFactors = FALSE)
source("/usr/share/pluto/config.R")
source("/usr/share/pluto/goofy/plot.common.R")
source("/usr/share/pluto/goofy/misc.common.R")

library(ggthemes)
library(quantmod)
library(reshape2)
library(ggrepel)
library(PerformanceAnalytics)

options(repr.plot.width=16, repr.plot.height=8)

fred<-Fred()
wb <- WorldBank()

# %%
# see example: https://nbviewer.jupyter.org/github/shyams80/plutons/blob/master/docs-R/WorldBank.ipynb

wb$Meta() %>%
    filter(INDICATOR_NAME %like% "CPI%") %>%
    select(COUNTRY_NAME, INDICATOR_NAME, COUNTRY_KEY, INDICATOR_KEY) %>%
    arrange(COUNTRY_NAME) %>%
    print(n=Inf)
# Out:
# # Source:     lazy query [?? x 4]
# # Database:   NORWAY:StockVizUs:R
# # Ordered by: COUNTRY_NAME
#     COUNTRY_NAME              INDICATOR_NAME           COUNTRY_KEY INDICATOR_KEY
#     <chr>                     <chr>                          <int>         <int>
#   1 Afghanistan               CPI Price, nominal                 2             3
#   2 Afghanistan               CPI Price, nominal, sea…           2             5
#   3 Afghanistan               CPI Price, % y-o-y, nom…           2             6
#   4 Albania                   CPI Price, nominal                 5             3
#   5 Albania                   CPI Price, nominal, sea…           5             5
#   6 Albania                   CPI Price, % y-o-y, nom…           5             6
#   7 Algeria                   CPI Price, nominal                84             3
#   8 Algeria                   CPI Price, nominal, sea…          84             5
#   9 Algeria                   CPI Price, % y-o-y, nom…          84             6
#  10 Angola                    CPI Price, nominal                 4             3
#  11 Angola                    CPI Price, nominal, sea…           4             5
#  12 Angola                    CPI Price, % y-o-y, nom…           4             6
#  13 Antigua and Barbuda       CPI Price, nominal                13             3
#  14 Antigua and Barbuda       CPI Price, nominal, sea…          13             5
#  15 Antigua and Barbuda       CPI Price, % y-o-y, nom…          13             6
#  16 Armenia                   CPI Price, nominal                11             3
#  17 Armenia                   CPI Price, nominal, sea…          11             5
#  18 Armenia                   CPI Price, % y-o-y, nom…          11             6
#  19 Aruba                     CPI Price, nominal                 1             3
#  20 Aruba                     CPI Price, nominal, sea…           1             5
#  21 Aruba                     CPI Price, % y-o-y, nom…           1             6
#  22 Austria                   CPI Price, nominal                15             3
#  23 Austria                   CPI Price, nominal, sea…          15             5
#  24 Austria                   CPI Price, % y-o-y, nom…          15             6
#  25 Azerbaijan                CPI Price, nominal                16             3
#  26 Azerbaijan                CPI Price, nominal, sea…          16             5
#  27 Azerbaijan                CPI Price, % y-o-y, nom…          16             6
#  28 Bahamas, The              CPI Price, nominal                27             3
#  29 Bahamas, The              CPI Price, nominal, sea…          27             5
#  30 Bahamas, The              CPI Price, % y-o-y, nom…          27             6
#  31 Bahrain                   CPI Price, nominal                26             3
#  32 Bahrain                   CPI Price, nominal, sea…          26             5
#  33 Bahrain                   CPI Price, % y-o-y, nom…          26             6
#  34 Bangladesh                CPI Price, nominal                23             3
#  35 Bangladesh                CPI Price, nominal, sea…          23             5
#  36 Bangladesh                CPI Price, % y-o-y, nom…          23             6
#  37 Barbados                  CPI Price, nominal                36             3
#  38 Barbados                  CPI Price, nominal, sea…          36             5
#  39 Barbados                  CPI Price, % y-o-y, nom…          36             6
#  40 Belarus                   CPI Price, nominal                30             3
#  41 Belarus                   CPI Price, nominal, sea…          30             5
#  42 Belarus                   CPI Price, % y-o-y, nom…          30             6
#  43 Belgium                   CPI Price, nominal                20             3
#  44 Belgium                   CPI Price, nominal, sea…          20             5
#  45 Belgium                   CPI Price, % y-o-y, nom…          20             6
#  46 Belize                    CPI Price, nominal                31             3
#  47 Belize                    CPI Price, nominal, sea…          31             5
#  48 Belize                    CPI Price, % y-o-y, nom…          31             6
#  49 Benin                     CPI Price, nominal                21             3
#  50 Benin                     CPI Price, nominal, sea…          21             5
#  51 Benin                     CPI Price, % y-o-y, nom…          21             6
#  52 Bhutan                    CPI Price, nominal                39             3
#  53 Bhutan                    CPI Price, nominal, sea…          39             5
#  54 Bhutan                    CPI Price, % y-o-y, nom…          39             6
#  55 Bolivia                   CPI Price, nominal                34             3
#  56 Bolivia                   CPI Price, nominal, sea…          34             5
#  57 Bolivia                   CPI Price, % y-o-y, nom…          34             6
#  58 Bosnia and Herzegovina    CPI Price, nominal                28             3
#  59 Bosnia and Herzegovina    CPI Price, nominal, sea…          28             5
#  60 Bosnia and Herzegovina    CPI Price, % y-o-y, nom…          28             6
#  61 Botswana                  CPI Price, nominal                40             3
#  62 Botswana                  CPI Price, nominal, sea…          40             5
#  63 Botswana                  CPI Price, % y-o-y, nom…          40             6
#  64 Brazil                    CPI Price, nominal                35             3
#  65 Brazil                    CPI Price, nominal, sea…          35             5
#  66 Brazil                    CPI Price, % y-o-y, nom…          35             6
#  67 Brunei Darussalam         CPI Price, nominal                37             3
#  68 Brunei Darussalam         CPI Price, nominal, sea…          37             5
#  69 Brunei Darussalam         CPI Price, % y-o-y, nom…          37             6
#  70 Bulgaria                  CPI Price, nominal                24             3
#  71 Bulgaria                  CPI Price, nominal, sea…          24             5
#  72 Bulgaria                  CPI Price, % y-o-y, nom…          24             6
#  73 Burkina Faso              CPI Price, nominal                22             3
#  74 Burkina Faso              CPI Price, nominal, sea…          22             5
#  75 Burkina Faso              CPI Price, % y-o-y, nom…          22             6
#  76 Burundi                   CPI Price, nominal                17             3
#  77 Burundi                   CPI Price, nominal, sea…          17             5
#  78 Burundi                   CPI Price, % y-o-y, nom…          17             6
#  79 Cabo Verde                CPI Price, nominal                59             3
#  80 Cabo Verde                CPI Price, nominal, sea…          59             5
#  81 Cabo Verde                CPI Price, % y-o-y, nom…          59             6
#  82 Cambodia                  CPI Price, nominal               149             3
#  83 Cambodia                  CPI Price, nominal, sea…         149             5
#  84 Cambodia                  CPI Price, % y-o-y, nom…         149             6
#  85 Cameroon                  CPI Price, nominal                54             3
#  86 Cameroon                  CPI Price, nominal, sea…          54             5
#  87 Cameroon                  CPI Price, % y-o-y, nom…          54             6
#  88 Canada                    CPI Price, nominal                43             3
#  89 Canada                    CPI Price, nominal, sea…          43             5
#  90 Canada                    CPI Price, % y-o-y, nom…          43             6
#  91 Central African Republic  CPI Price, nominal                42             3
#  92 Central African Republic  CPI Price, nominal, sea…          42             5
#  93 Central African Republic  CPI Price, % y-o-y, nom…          42             6
#  94 Chad                      CPI Price, nominal               266             3
#  95 Chad                      CPI Price, nominal, sea…         266             5
#  96 Chad                      CPI Price, % y-o-y, nom…         266             6
#  97 Chile                     CPI Price, nominal                49             3
#  98 Chile                     CPI Price, nominal, sea…          49             5
#  99 Chile                     CPI Price, % y-o-y, nom…          49             6
# 100 China                     CPI Price, nominal                50             3
# 101 China                     CPI Price, nominal, sea…          50             5
# 102 China                     CPI Price, % y-o-y, nom…          50             6
# 103 Colombia                  CPI Price, nominal                57             3
# 104 Colombia                  CPI Price, nominal, sea…          57             5
# 105 Colombia                  CPI Price, % y-o-y, nom…          57             6
# 106 Comoros                   CPI Price, nominal                58             3
# 107 Comoros                   CPI Price, nominal, sea…          58             5
# 108 Comoros                   CPI Price, % y-o-y, nom…          58             6
# 109 Congo, Dem. Rep.          CPI Price, nominal                55             3
# 110 Congo, Dem. Rep.          CPI Price, nominal, sea…          55             5
# 111 Congo, Dem. Rep.          CPI Price, % y-o-y, nom…          55             6
# 112 Congo, Rep.               CPI Price, nominal                56             3
# 113 Congo, Rep.               CPI Price, nominal, sea…          56             5
# 114 Congo, Rep.               CPI Price, % y-o-y, nom…          56             6
# 115 Costa Rica                CPI Price, nominal                60             3
# 116 Costa Rica                CPI Price, nominal, sea…          60             5
# 117 Costa Rica                CPI Price, % y-o-y, nom…          60             6
# 118 Cote d'Ivoire             CPI Price, nominal                51             3
# 119 Cote d'Ivoire             CPI Price, nominal, sea…          51             5
# 120 Cote d'Ivoire             CPI Price, % y-o-y, nom…          51             6
# 121 Croatia                   CPI Price, nominal               124             3
# 122 Croatia                   CPI Price, nominal, sea…         124             5
# 123 Croatia                   CPI Price, % y-o-y, nom…         124             6
# 124 Cyprus                    CPI Price, nominal                66             3
# 125 Cyprus                    CPI Price, nominal, sea…          66             5
# 126 Cyprus                    CPI Price, % y-o-y, nom…          66             6
# 127 Czech Republic            CPI Price, nominal                67             3
# 128 Czech Republic            CPI Price, nominal, sea…          67             5
# 129 Czech Republic            CPI Price, % y-o-y, nom…          67             6
# 130 Denmark                   CPI Price, nominal                77             3
# 131 Denmark                   CPI Price, nominal, sea…          77             5
# 132 Denmark                   CPI Price, % y-o-y, nom…          77             6
# 133 Djibouti                  CPI Price, nominal                72             3
# 134 Djibouti                  CPI Price, nominal, sea…          72             5
# 135 Djibouti                  CPI Price, % y-o-y, nom…          72             6
# 136 Dominica                  CPI Price, nominal                74             3
# 137 Dominica                  CPI Price, nominal, sea…          74             5
# 138 Dominica                  CPI Price, % y-o-y, nom…          74             6
# 139 Dominican Republic        CPI Price, nominal                79             3
# 140 Dominican Republic        CPI Price, nominal, sea…          79             5
# 141 Dominican Republic        CPI Price, % y-o-y, nom…          79             6
# 142 East Asia & Pacific (exc… CPI Price, nominal                85             3
# 143 East Asia & Pacific (exc… CPI Price, % y-o-y, med…          85             4
# 144 East Asia & Pacific (exc… CPI Price, nominal, sea…          85             5
# 145 Ecuador                   CPI Price, nominal                90             3
# 146 Ecuador                   CPI Price, nominal, sea…          90             5
# 147 Ecuador                   CPI Price, % y-o-y, nom…          90             6
# 148 Egypt, Arab Rep.          CPI Price, nominal                91             3
# 149 Egypt, Arab Rep.          CPI Price, nominal, sea…          91             5
# 150 Egypt, Arab Rep.          CPI Price, % y-o-y, nom…          91             6
# 151 El Salvador               CPI Price, nominal               247             3
# 152 El Salvador               CPI Price, nominal, sea…         247             5
# 153 El Salvador               CPI Price, % y-o-y, nom…         247             6
# 154 Equatorial Guinea         CPI Price, nominal               113             3
# 155 Equatorial Guinea         CPI Price, nominal, sea…         113             5
# 156 Equatorial Guinea         CPI Price, % y-o-y, nom…         113             6
# 157 Estonia                   CPI Price, nominal                95             3
# 158 Estonia                   CPI Price, nominal, sea…          95             5
# 159 Estonia                   CPI Price, % y-o-y, nom…          95             6
# 160 Eswatini                  CPI Price, nominal               260             3
# 161 Eswatini                  CPI Price, nominal, sea…         260             5
# 162 Eswatini                  CPI Price, % y-o-y, nom…         260             6
# 163 Ethiopia                  CPI Price, nominal                96             3
# 164 Ethiopia                  CPI Price, nominal, sea…          96             5
# 165 Ethiopia                  CPI Price, % y-o-y, nom…          96             6
# 166 Europe & Central Asia (e… CPI Price, nominal                88             3
# 167 Europe & Central Asia (e… CPI Price, % y-o-y, med…          88             4
# 168 Europe & Central Asia (e… CPI Price, nominal, sea…          88             5
# 169 Fiji                      CPI Price, nominal               100             3
# 170 Fiji                      CPI Price, nominal, sea…         100             5
# 171 Fiji                      CPI Price, % y-o-y, nom…         100             6
# 172 Finland                   CPI Price, nominal                99             3
# 173 Finland                   CPI Price, nominal, sea…          99             5
# 174 Finland                   CPI Price, % y-o-y, nom…          99             6
# 175 France                    CPI Price, nominal               101             3
# 176 France                    CPI Price, nominal, sea…         101             5
# 177 France                    CPI Price, % y-o-y, nom…         101             6
# 178 Gabon                     CPI Price, nominal               105             3
# 179 Gabon                     CPI Price, nominal, sea…         105             5
# 180 Gabon                     CPI Price, % y-o-y, nom…         105             6
# 181 Gambia, The               CPI Price, nominal               111             3
# 182 Gambia, The               CPI Price, nominal, sea…         111             5
# 183 Gambia, The               CPI Price, % y-o-y, nom…         111             6
# 184 Georgia                   CPI Price, nominal               107             3
# 185 Georgia                   CPI Price, nominal, sea…         107             5
# 186 Georgia                   CPI Price, % y-o-y, nom…         107             6
# 187 Germany                   CPI Price, nominal                70             3
# 188 Germany                   CPI Price, nominal, sea…          70             5
# 189 Germany                   CPI Price, % y-o-y, nom…          70             6
# 190 Greece                    CPI Price, nominal               114             3
# 191 Greece                    CPI Price, nominal, sea…         114             5
# 192 Greece                    CPI Price, % y-o-y, nom…         114             6
# 193 Grenada                   CPI Price, nominal               115             3
# 194 Grenada                   CPI Price, nominal, sea…         115             5
# 195 Grenada                   CPI Price, % y-o-y, nom…         115             6
# 196 Guatemala                 CPI Price, nominal               117             3
# 197 Guatemala                 CPI Price, nominal, sea…         117             5
# 198 Guatemala                 CPI Price, % y-o-y, nom…         117             6
# 199 Guinea                    CPI Price, nominal               110             3
# 200 Guinea                    CPI Price, nominal, sea…         110             5
# 201 Guinea                    CPI Price, % y-o-y, nom…         110             6
# 202 Guinea-Bissau             CPI Price, nominal               112             3
# 203 Guinea-Bissau             CPI Price, nominal, sea…         112             5
# 204 Guinea-Bissau             CPI Price, % y-o-y, nom…         112             6
# 205 Guyana                    CPI Price, nominal               119             3
# 206 Guyana                    CPI Price, nominal, sea…         119             5
# 207 Guyana                    CPI Price, % y-o-y, nom…         119             6
# 208 Haiti                     CPI Price, nominal               125             3
# 209 Haiti                     CPI Price, nominal, sea…         125             5
# 210 Haiti                     CPI Price, % y-o-y, nom…         125             6
# 211 Honduras                  CPI Price, nominal               122             3
# 212 Honduras                  CPI Price, nominal, sea…         122             5
# 213 Honduras                  CPI Price, % y-o-y, nom…         122             6
# 214 Hong Kong SAR, China      CPI Price, nominal               121             3
# 215 Hong Kong SAR, China      CPI Price, nominal, sea…         121             5
# 216 Hong Kong SAR, China      CPI Price, % y-o-y, nom…         121             6
# 217 Hungary                   CPI Price, nominal               126             3
# 218 Hungary                   CPI Price, nominal, sea…         126             5
# 219 Hungary                   CPI Price, % y-o-y, nom…         126             6
# 220 Iceland                   CPI Price, nominal               140             3
# 221 Iceland                   CPI Price, nominal, sea…         140             5
# 222 Iceland                   CPI Price, % y-o-y, nom…         140             6
# 223 India                     CPI Price, nominal               135             3
# 224 India                     CPI Price, nominal, sea…         135             5
# 225 India                     CPI Price, % y-o-y, nom…         135             6
# 226 Indonesia                 CPI Price, nominal               132             3
# 227 Indonesia                 CPI Price, nominal, sea…         132             5
# 228 Indonesia                 CPI Price, % y-o-y, nom…         132             6
# 229 Iran, Islamic Rep.        CPI Price, nominal               138             3
# 230 Iran, Islamic Rep.        CPI Price, nominal, sea…         138             5
# 231 Iran, Islamic Rep.        CPI Price, % y-o-y, nom…         138             6
# 232 Iraq                      CPI Price, nominal               139             3
# 233 Iraq                      CPI Price, nominal, sea…         139             5
# 234 Iraq                      CPI Price, % y-o-y, nom…         139             6
# 235 Ireland                   CPI Price, nominal               137             3
# 236 Ireland                   CPI Price, nominal, sea…         137             5
# 237 Ireland                   CPI Price, % y-o-y, nom…         137             6
# 238 Israel                    CPI Price, nominal               141             3
# 239 Israel                    CPI Price, nominal, sea…         141             5
# 240 Israel                    CPI Price, % y-o-y, nom…         141             6
# 241 Italy                     CPI Price, nominal               142             3
# 242 Italy                     CPI Price, nominal, sea…         142             5
# 243 Italy                     CPI Price, % y-o-y, nom…         142             6
# 244 Jamaica                   CPI Price, nominal               143             3
# 245 Jamaica                   CPI Price, nominal, sea…         143             5
# 246 Jamaica                   CPI Price, % y-o-y, nom…         143             6
# 247 Japan                     CPI Price, nominal               145             3
# 248 Japan                     CPI Price, nominal, sea…         145             5
# 249 Japan                     CPI Price, % y-o-y, nom…         145             6
# 250 Jordan                    CPI Price, nominal               144             3
# 251 Jordan                    CPI Price, nominal, sea…         144             5
# 252 Jordan                    CPI Price, % y-o-y, nom…         144             6
# 253 Kazakhstan                CPI Price, nominal               146             3
# 254 Kazakhstan                CPI Price, nominal, sea…         146             5
# 255 Kazakhstan                CPI Price, % y-o-y, nom…         146             6
# 256 Kenya                     CPI Price, nominal               147             3
# 257 Kenya                     CPI Price, nominal, sea…         147             5
# 258 Kenya                     CPI Price, % y-o-y, nom…         147             6
# 259 Kiribati                  CPI Price, nominal               150             3
# 260 Kiribati                  CPI Price, nominal, sea…         150             5
# 261 Kiribati                  CPI Price, % y-o-y, nom…         150             6
# 262 Korea, Rep.               CPI Price, nominal               152             3
# 263 Korea, Rep.               CPI Price, nominal, sea…         152             5
# 264 Korea, Rep.               CPI Price, % y-o-y, nom…         152             6
# 265 Kyrgyz Republic           CPI Price, nominal               148             3
# 266 Kyrgyz Republic           CPI Price, nominal, sea…         148             5
# 267 Kyrgyz Republic           CPI Price, % y-o-y, nom…         148             6
# 268 Lao PDR                   CPI Price, nominal               155             3
# 269 Lao PDR                   CPI Price, nominal, sea…         155             5
# 270 Lao PDR                   CPI Price, % y-o-y, nom…         155             6
# 271 Latin America & Caribbea… CPI Price, nominal               154             3
# 272 Latin America & Caribbea… CPI Price, % y-o-y, med…         154             4
# 273 Latin America & Caribbea… CPI Price, nominal, sea…         154             5
# 274 Latvia                    CPI Price, nominal               172             3
# 275 Latvia                    CPI Price, nominal, sea…         172             5
# 276 Latvia                    CPI Price, % y-o-y, nom…         172             6
# 277 Lebanon                   CPI Price, nominal               156             3
# 278 Lebanon                   CPI Price, nominal, sea…         156             5
# 279 Lebanon                   CPI Price, % y-o-y, nom…         156             6
# 280 Lesotho                   CPI Price, nominal               168             3
# 281 Lesotho                   CPI Price, nominal, sea…         168             5
# 282 Lesotho                   CPI Price, % y-o-y, nom…         168             6
# 283 Liberia                   CPI Price, nominal               157             3
# 284 Liberia                   CPI Price, nominal, sea…         157             5
# 285 Liberia                   CPI Price, % y-o-y, nom…         157             6
# 286 Libya                     CPI Price, nominal               158             3
# 287 Libya                     CPI Price, nominal, sea…         158             5
# 288 Libya                     CPI Price, % y-o-y, nom…         158             6
# 289 Lithuania                 CPI Price, nominal               170             3
# 290 Lithuania                 CPI Price, nominal, sea…         170             5
# 291 Lithuania                 CPI Price, % y-o-y, nom…         170             6
# 292 Low income                CPI Price, nominal               163             3
# 293 Low income                CPI Price, % y-o-y, med…         163             4
# 294 Low income                CPI Price, nominal, sea…         163             5
# 295 Lower middle income       CPI Price, nominal               166             3
# 296 Lower middle income       CPI Price, % y-o-y, med…         166             4
# 297 Lower middle income       CPI Price, nominal, sea…         166             5
# 298 Luxembourg                CPI Price, nominal               171             3
# 299 Luxembourg                CPI Price, nominal, sea…         171             5
# 300 Luxembourg                CPI Price, % y-o-y, nom…         171             6
# 301 Macao SAR, China          CPI Price, nominal               173             3
# 302 Macao SAR, China          CPI Price, nominal, sea…         173             5
# 303 Macao SAR, China          CPI Price, % y-o-y, nom…         173             6
# 304 Madagascar                CPI Price, nominal               180             3
# 305 Madagascar                CPI Price, nominal, sea…         180             5
# 306 Madagascar                CPI Price, % y-o-y, nom…         180             6
# 307 Malawi                    CPI Price, nominal               197             3
# 308 Malawi                    CPI Price, nominal, sea…         197             5
# 309 Malawi                    CPI Price, % y-o-y, nom…         197             6
# 310 Malaysia                  CPI Price, nominal               198             3
# 311 Malaysia                  CPI Price, nominal, sea…         198             5
# 312 Malaysia                  CPI Price, % y-o-y, nom…         198             6
# 313 Maldives                  CPI Price, nominal               181             3
# 314 Maldives                  CPI Price, nominal, sea…         181             5
# 315 Maldives                  CPI Price, % y-o-y, nom…         181             6
# 316 Mali                      CPI Price, nominal               187             3
# 317 Mali                      CPI Price, nominal, sea…         187             5
# 318 Mali                      CPI Price, % y-o-y, nom…         187             6
# 319 Malta                     CPI Price, nominal               188             3
# 320 Malta                     CPI Price, nominal, sea…         188             5
# 321 Malta                     CPI Price, % y-o-y, nom…         188             6
# 322 Mauritania                CPI Price, nominal               195             3
# 323 Mauritania                CPI Price, nominal, sea…         195             5
# 324 Mauritania                CPI Price, % y-o-y, nom…         195             6
# 325 Mauritius                 CPI Price, nominal               196             3
# 326 Mauritius                 CPI Price, nominal, sea…         196             5
# 327 Mauritius                 CPI Price, % y-o-y, nom…         196             6
# 328 Mexico                    CPI Price, nominal               183             3
# 329 Mexico                    CPI Price, nominal, sea…         183             5
# 330 Mexico                    CPI Price, % y-o-y, nom…         183             6
# 331 Middle East & North Afri… CPI Price, nominal               190             3
# 332 Middle East & North Afri… CPI Price, % y-o-y, med…         190             4
# 333 Middle East & North Afri… CPI Price, nominal, sea…         190             5
# 334 Middle income             CPI Price, nominal               185             3
# 335 Middle income             CPI Price, % y-o-y, med…         185             4
# 336 Middle income             CPI Price, nominal, sea…         185             5
# 337 Moldova                   CPI Price, nominal               178             3
# 338 Moldova                   CPI Price, nominal, sea…         178             5
# 339 Moldova                   CPI Price, % y-o-y, nom…         178             6
# 340 Mongolia                  CPI Price, nominal               192             3
# 341 Mongolia                  CPI Price, nominal, sea…         192             5
# 342 Mongolia                  CPI Price, % y-o-y, nom…         192             6
# 343 Morocco                   CPI Price, nominal               175             3
# 344 Morocco                   CPI Price, nominal, sea…         175             5
# 345 Morocco                   CPI Price, % y-o-y, nom…         175             6
# 346 Mozambique                CPI Price, nominal               194             3
# 347 Mozambique                CPI Price, nominal, sea…         194             5
# 348 Mozambique                CPI Price, % y-o-y, nom…         194             6
# 349 Myanmar                   CPI Price, nominal               189             3
# 350 Myanmar                   CPI Price, nominal, sea…         189             5
# 351 Myanmar                   CPI Price, % y-o-y, nom…         189             6
# 352 Namibia                   CPI Price, nominal               201             3
# 353 Namibia                   CPI Price, nominal, sea…         201             5
# 354 Namibia                   CPI Price, % y-o-y, nom…         201             6
# 355 Nepal                     CPI Price, nominal               209             3
# 356 Nepal                     CPI Price, nominal, sea…         209             5
# 357 Nepal                     CPI Price, % y-o-y, nom…         209             6
# 358 Netherlands               CPI Price, nominal               206             3
# 359 Netherlands               CPI Price, nominal, sea…         206             5
# 360 Netherlands               CPI Price, % y-o-y, nom…         206             6
# 361 New Caledonia             CPI Price, nominal               202             3
# 362 New Caledonia             CPI Price, nominal, sea…         202             5
# 363 New Caledonia             CPI Price, % y-o-y, nom…         202             6
# 364 Nicaragua                 CPI Price, nominal               205             3
# 365 Nicaragua                 CPI Price, nominal, sea…         205             5
# 366 Nicaragua                 CPI Price, % y-o-y, nom…         205             6
# 367 Niger                     CPI Price, nominal               203             3
# 368 Niger                     CPI Price, nominal, sea…         203             5
# 369 Niger                     CPI Price, % y-o-y, nom…         203             6
# 370 Nigeria                   CPI Price, nominal               204             3
# 371 Nigeria                   CPI Price, nominal, sea…         204             5
# 372 Nigeria                   CPI Price, % y-o-y, nom…         204             6
# 373 North Macedonia           CPI Price, nominal               186             3
# 374 North Macedonia           CPI Price, nominal, sea…         186             5
# 375 North Macedonia           CPI Price, % y-o-y, nom…         186             6
# 376 Norway                    CPI Price, nominal               208             3
# 377 Norway                    CPI Price, nominal, sea…         208             5
# 378 Norway                    CPI Price, % y-o-y, nom…         208             6
# 379 Oman                      CPI Price, nominal               215             3
# 380 Oman                      CPI Price, nominal, sea…         215             5
# 381 Oman                      CPI Price, % y-o-y, nom…         215             6
# 382 Pakistan                  CPI Price, nominal               217             3
# 383 Pakistan                  CPI Price, nominal, sea…         217             5
# 384 Pakistan                  CPI Price, % y-o-y, nom…         217             6
# 385 Panama                    CPI Price, nominal               218             3
# 386 Panama                    CPI Price, nominal, sea…         218             5
# 387 Panama                    CPI Price, % y-o-y, nom…         218             6
# 388 Paraguay                  CPI Price, nominal               228             3
# 389 Paraguay                  CPI Price, nominal, sea…         228             5
# 390 Paraguay                  CPI Price, % y-o-y, nom…         228             6
# 391 Peru                      CPI Price, nominal               219             3
# 392 Peru                      CPI Price, nominal, sea…         219             5
# 393 Peru                      CPI Price, % y-o-y, nom…         219             6
# 394 Philippines               CPI Price, nominal               220             3
# 395 Philippines               CPI Price, nominal, sea…         220             5
# 396 Philippines               CPI Price, % y-o-y, nom…         220             6
# 397 Poland                    CPI Price, nominal               223             3
# 398 Poland                    CPI Price, nominal, sea…         223             5
# 399 Poland                    CPI Price, % y-o-y, nom…         223             6
# 400 Portugal                  CPI Price, nominal               227             3
# 401 Portugal                  CPI Price, nominal, sea…         227             5
# 402 Portugal                  CPI Price, % y-o-y, nom…         227             6
# 403 Qatar                     CPI Price, nominal               233             3
# 404 Qatar                     CPI Price, nominal, sea…         233             5
# 405 Qatar                     CPI Price, % y-o-y, nom…         233             6
# 406 Romania                   CPI Price, nominal               234             3
# 407 Romania                   CPI Price, nominal, sea…         234             5
# 408 Romania                   CPI Price, % y-o-y, nom…         234             6
# 409 Russian Federation        CPI Price, nominal               237             3
# 410 Russian Federation        CPI Price, nominal, sea…         237             5
# 411 Russian Federation        CPI Price, % y-o-y, nom…         237             6
# 412 Rwanda                    CPI Price, nominal               238             3
# 413 Rwanda                    CPI Price, nominal, sea…         238             5
# 414 Rwanda                    CPI Price, % y-o-y, nom…         238             6
# 415 Samoa                     CPI Price, nominal               298             3
# 416 Samoa                     CPI Price, nominal, sea…         298             5
# 417 Samoa                     CPI Price, % y-o-y, nom…         298             6
# 418 San Marino                CPI Price, nominal               248             3
# 419 San Marino                CPI Price, nominal, sea…         248             5
# 420 San Marino                CPI Price, % y-o-y, nom…         248             6
# 421 Sao Tome and Principe     CPI Price, nominal               255             3
# 422 Sao Tome and Principe     CPI Price, nominal, sea…         255             5
# 423 Sao Tome and Principe     CPI Price, % y-o-y, nom…         255             6
# 424 Saudi Arabia              CPI Price, nominal               240             3
# 425 Saudi Arabia              CPI Price, nominal, sea…         240             5
# 426 Saudi Arabia              CPI Price, % y-o-y, nom…         240             6
# 427 Senegal                   CPI Price, nominal               243             3
# 428 Senegal                   CPI Price, nominal, sea…         243             5
# 429 Senegal                   CPI Price, % y-o-y, nom…         243             6
# 430 Seychelles                CPI Price, nominal               263             3
# 431 Seychelles                CPI Price, nominal, sea…         263             5
# 432 Seychelles                CPI Price, % y-o-y, nom…         263             6
# 433 Sierra Leone              CPI Price, nominal               246             3
# 434 Sierra Leone              CPI Price, nominal, sea…         246             5
# 435 Sierra Leone              CPI Price, % y-o-y, nom…         246             6
# 436 Singapore                 CPI Price, nominal               244             3
# 437 Singapore                 CPI Price, nominal, sea…         244             5
# 438 Singapore                 CPI Price, % y-o-y, nom…         244             6
# 439 Slovak Republic           CPI Price, nominal               257             3
# 440 Slovak Republic           CPI Price, nominal, sea…         257             5
# 441 Slovak Republic           CPI Price, % y-o-y, nom…         257             6
# 442 Slovenia                  CPI Price, nominal               258             3
# 443 Slovenia                  CPI Price, nominal, sea…         258             5
# 444 Slovenia                  CPI Price, % y-o-y, nom…         258             6
# 445 Small states              CPI Price, nominal               254             3
# 446 Small states              CPI Price, % y-o-y, med…         254             4
# 447 Small states              CPI Price, nominal, sea…         254             5
# 448 Solomon Islands           CPI Price, nominal               245             3
# 449 Solomon Islands           CPI Price, nominal, sea…         245             5
# 450 Solomon Islands           CPI Price, % y-o-y, nom…         245             6
# 451 South Africa              CPI Price, nominal               302             3
# 452 South Africa              CPI Price, nominal, sea…         302             5
# 453 South Africa              CPI Price, % y-o-y, nom…         302             6
# 454 South Asia                CPI Price, nominal               239             3
# 455 South Asia                CPI Price, % y-o-y, med…         239             4
# 456 South Asia                CPI Price, nominal, sea…         239             5
# 457 Spain                     CPI Price, nominal                94             3
# 458 Spain                     CPI Price, nominal, sea…          94             5
# 459 Spain                     CPI Price, % y-o-y, nom…          94             6
# 460 Sri Lanka                 CPI Price, nominal               165             3
# 461 Sri Lanka                 CPI Price, nominal, sea…         165             5
# 462 Sri Lanka                 CPI Price, % y-o-y, nom…         165             6
# 463 St. Kitts and Nevis       CPI Price, nominal               151             3
# 464 St. Kitts and Nevis       CPI Price, nominal, sea…         151             5
# 465 St. Kitts and Nevis       CPI Price, % y-o-y, nom…         151             6
# 466 St. Lucia                 CPI Price, nominal               159             3
# 467 St. Lucia                 CPI Price, nominal, sea…         159             5
# 468 St. Lucia                 CPI Price, % y-o-y, nom…         159             6
# 469 St. Vincent and the Gren… CPI Price, nominal               291             3
# 470 St. Vincent and the Gren… CPI Price, nominal, sea…         291             5
# 471 St. Vincent and the Gren… CPI Price, % y-o-y, nom…         291             6
# 472 Sudan                     CPI Price, nominal               242             3
# 473 Sudan                     CPI Price, nominal, sea…         242             5
# 474 Sudan                     CPI Price, % y-o-y, nom…         242             6
# 475 Suriname                  CPI Price, nominal               256             3
# 476 Suriname                  CPI Price, nominal, sea…         256             5
# 477 Suriname                  CPI Price, % y-o-y, nom…         256             6
# 478 Sweden                    CPI Price, nominal               259             3
# 479 Sweden                    CPI Price, nominal, sea…         259             5
# 480 Sweden                    CPI Price, % y-o-y, nom…         259             6
# 481 Switzerland               CPI Price, nominal                47             3
# 482 Switzerland               CPI Price, nominal, sea…          47             5
# 483 Switzerland               CPI Price, % y-o-y, nom…          47             6
# 484 Syrian Arab Republic      CPI Price, nominal               264             3
# 485 Syrian Arab Republic      CPI Price, nominal, sea…         264             5
# 486 Syrian Arab Republic      CPI Price, % y-o-y, nom…         264             6
# 487 Taiwan, China             CPI Price, nominal               283             3
# 488 Taiwan, China             CPI Price, nominal, sea…         283             5
# 489 Taiwan, China             CPI Price, % y-o-y, nom…         283             6
# 490 Tajikistan                CPI Price, nominal               271             3
# 491 Tajikistan                CPI Price, nominal, sea…         271             5
# 492 Tajikistan                CPI Price, % y-o-y, nom…         271             6
# 493 Thailand                  CPI Price, nominal               270             3
# 494 Thailand                  CPI Price, nominal, sea…         270             5
# 495 Thailand                  CPI Price, % y-o-y, nom…         270             6
# 496 Timor-Leste               CPI Price, nominal               274             3
# 497 Timor-Leste               CPI Price, nominal, sea…         274             5
# 498 Timor-Leste               CPI Price, % y-o-y, nom…         274             6
# 499 Togo                      CPI Price, nominal               269             3
# 500 Togo                      CPI Price, nominal, sea…         269             5
# 501 Togo                      CPI Price, % y-o-y, nom…         269             6
# 502 Tonga                     CPI Price, nominal               276             3
# 503 Tonga                     CPI Price, nominal, sea…         276             5
# 504 Tonga                     CPI Price, % y-o-y, nom…         276             6
# 505 Trinidad and Tobago       CPI Price, nominal               279             3
# 506 Trinidad and Tobago       CPI Price, nominal, sea…         279             5
# 507 Trinidad and Tobago       CPI Price, % y-o-y, nom…         279             6
# 508 Tunisia                   CPI Price, nominal               280             3
# 509 Tunisia                   CPI Price, nominal, sea…         280             5
# 510 Tunisia                   CPI Price, % y-o-y, nom…         280             6
# 511 Turkey                    CPI Price, nominal               281             3
# 512 Turkey                    CPI Price, nominal, sea…         281             5
# 513 Turkey                    CPI Price, % y-o-y, nom…         281             6
# 514 Uganda                    CPI Price, nominal               285             3
# 515 Uganda                    CPI Price, nominal, sea…         285             5
# 516 Uganda                    CPI Price, % y-o-y, nom…         285             6
# 517 Ukraine                   CPI Price, nominal               286             3
# 518 Ukraine                   CPI Price, nominal, sea…         286             5
# 519 Ukraine                   CPI Price, % y-o-y, nom…         286             6
# 520 United Arab Emirates      CPI Price, nominal                 9             3
# 521 United Arab Emirates      CPI Price, nominal, sea…           9             5
# 522 United Arab Emirates      CPI Price, % y-o-y, nom…           9             6
# 523 United Kingdom            CPI Price, nominal               106             3
# 524 United Kingdom            CPI Price, nominal, sea…         106             5
# 525 United Kingdom            CPI Price, % y-o-y, nom…         106             6
# 526 United States             CPI Price, nominal               289             3
# 527 United States             CPI Price, nominal, sea…         289             5
# 528 United States             CPI Price, % y-o-y, nom…         289             6
# 529 Upper middle income       CPI Price, nominal               287             3
# 530 Upper middle income       CPI Price, % y-o-y, med…         287             4
# 531 Upper middle income       CPI Price, nominal, sea…         287             5
# 532 Uruguay                   CPI Price, nominal               288             3
# 533 Uruguay                   CPI Price, nominal, sea…         288             5
# 534 Uruguay                   CPI Price, % y-o-y, nom…         288             6
# 535 Venezuela, RB             CPI Price, nominal               292             3
# 536 Venezuela, RB             CPI Price, nominal, sea…         292             5
# 537 Venezuela, RB             CPI Price, % y-o-y, nom…         292             6
# 538 Vietnam                   CPI Price, nominal               295             3
# 539 Vietnam                   CPI Price, nominal, sea…         295             5
# 540 Vietnam                   CPI Price, % y-o-y, nom…         295             6
# 541 Yemen, Rep.               CPI Price, nominal               301             3
# 542 Yemen, Rep.               CPI Price, nominal, sea…         301             5
# 543 Yemen, Rep.               CPI Price, % y-o-y, nom…         301             6
# 544 Zambia                    CPI Price, nominal               303             3
# 545 Zambia                    CPI Price, nominal, sea…         303             5
# 546 Zambia                    CPI Price, % y-o-y, nom…         303             6

# %%
#India: 135, US: 289. KEY: 6

cpiInflation <- wb$TimeSeries() %>%
    full_join(wb$TimeSeries(), by=c('INDICATOR_KEY', 'YEAR')) %>%
    filter(COUNTRY_KEY.x == 135 & COUNTRY_KEY.y == 289 & INDICATOR_KEY == 6) %>%
    select(YEAR, INDIA = VALUE.x, US = VALUE.y) %>%
    arrange(YEAR) %>%
    collect() %>%
    as.data.frame()

print(cpiInflation)
# Out:
#    YEAR   INDIA      US
# 1  1987  8.7938  3.5782
# 2  1988  9.3960  4.1000
# 3  1989  3.2747  4.7911
# 4  1990  8.9651  5.4192
# 5  1991 13.8644  4.2158
# 6  1992 11.7933  3.0416
# 7  1993  6.3642  2.9697
# 8  1994  6.3400  2.5956
# 9  1995 11.3395  2.8054
# 10 1996  8.8972  2.9367
# 11 1997  5.6487  2.3376
# 12 1998  4.4739  1.5470
# 13 1999  5.9058  2.1931
# 14 2000  5.9895  3.3667
# 15 2001  3.6844  2.8166
# 16 2002  5.2034  1.5957
# 17 2003  4.3249  2.2980
# 18 2004  3.8532  2.6676
# 19 2005  3.7438  3.3658
# 20 2006  6.0617  3.2221
# 21 2007  5.9915  2.8706
# 22 2008  8.5729  3.8150
# 23 2009  9.7268 -0.3204
# 24 2010 10.3605  1.6366
# 25 2011  8.3140  3.1397
# 26 2012  9.3823  2.0732
# 27 2013 10.1005  1.4660
# 28 2014  6.4232  1.6118
# 29 2015  4.9105  0.1209
# 30 2016  4.9489  1.2716
# 31 2017  3.3259  2.1387
# 32 2018  3.3429  1.8910
# 33 2019  2.3848  1.3531

# %%
mDf <- melt(cpiInflation, id='YEAR')
ggplot(mDf, aes(x=YEAR, y=value, fill=variable)) +
    theme_economist() +
    geom_bar(stat="identity", position=position_dodge()) +
    scale_x_continuous(labels=cpiInflation$YEAR, breaks=cpiInflation$YEAR) +
    geom_text_repel(aes(label= round(value, 2)), position = position_dodge(0.9)) +
    labs(x='', y='(%)', fill='', title="CPI Inflation", 
         subtitle="World Bank Data") +
    annotate("text", x=max(cpiInflation$YEAR), y=min(mDf$value), 
             label = "@StockViz", hjust=1.1, vjust=-1.1, 
             col="white", cex=6, fontface = "bold", alpha = 0.8)
# Out:
# plot without title

# %% [markdown]
# This notebook was created using [pluto](https://pluto.studio). Thank you for playing fair!
